# %% [markdown]
# # Build your own concordance
#
# It took 500 Dominican munks to write the first concordance of the Latin bible, and it took Rabbi Mordecai Nathan 10 years to write the first concordance of the Hebrew bible. With Python, it only takes a matter of seconds to find words in a text, along with the surrounding words.
#
# Run each cell in this notebook one at a time, in order. If something in one cell doesn't work right, it might be because you have overwritten a variable, so try going back and running all the previous cells again.
#
# First run the code and check that everything works. Then, try modifying the code. Start with the first challenges, and then continue in order. Feel free to work together, and see how far you can get. The important thing is to learn, not to solve all the challenges!

# %%
# install the natural language toolkit package (nltk), which has a copy of several texts, 
#including the King James Bible

# %pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/ucloud/.local/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /home/ucloud/.local/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/ucloud/.local/lib/python3.12/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /home/ucloud/.local/lib/python3.12/site-packages (from nltk) (4.66.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the nltk package so that it is accessible to Python, and download a collection of texts from Project Gutenberg
import nltk
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to /home/ucloud/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.
# True

# %%
# Create a variable called "bible" which contains the text of the King James bible.
bible = nltk.corpus.gutenberg.raw('bible-kjv.txt')

# make all characters lowercase
bible = bible.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
bible = bible.replace('\n', ' ')

# split up the text into a long list of individual words
bible = bible.split(' ')

# %%
# make a variable called "concordance", and fill it with every occurrence of the phrase "this world", and a few words preceeding and following "this world"
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        if bible[i-1] == "this":
            concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['for the children of this world are in their generation',
#  'them, the children of this world marry, and are given',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'for the prince of this world cometh, and hath nothing',
#  'because the prince of this world is judged.  16:12',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'for the fashion of this world passeth away.  7:32',
#  'whom the god of this world hath blinded the minds',
#  'chosen the poor of this world rich in faith, and',
#  'saying, the kingdoms of this world are become the kingdoms']

# %%
# let's see how many instances of the phrase "this world" were found
len(concordance)
# Out:
# 13

# %% [markdown]
# Let's try again, but this time let's just search for "world" by itself, not "this world".

# %%
concordance = []
for i, val in enumerate(bible):
    if val == "world":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
# take a look at what the algorithm has found
concordance
# Out:
# ['and he hath set the world upon them.  2:9',
#  'appeared, the foundations of the world were discovered, at the',
#  'him, all the earth: the world also shall be stable,',
#  'upon the face of the world in the earth. ',
#  'and he shall judge the world in righteousness, he shall',
#  'and the foundations of the world were discovered at thy',
#  'all the ends of the world shall remember and turn',
#  'all the inhabitants of the world stand in awe of',
#  'not tell thee: for the world is mine, and the',
#  'is thine: as for the world and the fulness thereof,',
#  'he hath girded himself: the world also is stablished, that',
#  'that the lord reigneth: the world also shall be established',
#  'earth: he shall judge the world with righteousness, and the',
#  'also he hath set the world in their heart, so',
#  'and i will punish the world for their evil, and',
#  'kingdoms; 14:17 that made the world as a wilderness, and',
#  'fill the face of the world with cities.  14:22',
#  'all the kingdoms of the world upon the face of',
#  'mourneth and fadeth away, the world languisheth and fadeth away,',
#  'earth, the inhabitants of the world will learn righteousness. ',
#  'have the inhabitants of the world fallen.  26:19 thy',
#  'fill the face of the world with fruit.  27:7',
#  'not be ashamed nor confounded world without end.  45:18',
#  'since the beginning of the world men have not heard,',
#  'power, he hath established the world by his wisdom, and',
#  'power, he hath established the world by his wisdom, and',
#  'this world, neither in the world to come.  12:33',
#  ' 18:7 woe unto the world because of offences! for',
#  'be preached in all the world for a witness unto',
#  'since the beginning of the world to this time, no,',
#  'with persecutions; and in the world to come eternal life.',
#  'which have been since the world began: 1:71 that we',
#  'caesar augustus that all the world should be taxed. ',
#  'all the kingdoms of the world in a moment of',
#  'do the nations of the world seek after: and your',
#  'for the children of this world are in their generation',
#  'present time, and in the world to come life everlasting.',
#  'them, the children of this world marry, and are given',
#  'in the world, and the world was made by him,',
#  'made by him, and the world knew him not. ',
#  'not his son into the world to condemn the world;',
#  'the world; but that the world through him might be',
#  'alway ready.  7:7 the world cannot hate you; but',
#  'and i speak to the world those things which i',
#  'heareth.  9:32 since the world began was it not',
#  'ye prevail nothing? behold, the world is gone after him.',
#  'hateth his life in this world shall keep it unto',
#  'shall the prince of this world be cast out. ',
#  'should depart out of this world unto the father, having',
#  'spirit of truth; whom the world cannot receive, because it',
#  'a little while, and the world seeth me no more;',
#  'unto you: not as the world giveth, give i unto',
#  'for the prince of this world cometh, and hath nothing',
#  ' 14:31 but that the world may know that i',
#  'another.  15:18 if the world hate you, ye know',
#  'were of the world, the world would love his own:',
#  'of the world, therefore the world hateth you.  15:20',
#  'come, he will reprove the world of sin, and of',
#  'because the prince of this world is judged.  16:12',
#  'weep and lament, but the world shall rejoice: and ye',
#  'have peace.  in the world ye shall have tribulation:',
#  'had with thee before the world was.  17:6 i',
#  'them thy word; and the world hath hated them, because',
#  'one in us: that the world may believe that thou',
#  'in one; and that the world may know that thou',
#  '17:25 o righteous father, the world hath not known thee:',
#  'i suppose that even the world itself could not contain',
#  'his holy prophets since the world began.  3:22 for',
#  'these that have turned the world upside down are come',
#  '17:24 god that made the world and all things therein,',
#  'which he will judge the world in righteousness by that',
#  'whom all asia and the world worshippeth.  19:28 and',
#  'from the creation of the world are clearly seen, being',
#  'be stopped, and all the world may become guilty before',
#  'was kept secret since the world began, 16:26 but now',
#  'the wisdom of god the world by wisdom knew not',
#  'the foolish things of the world to confound the wise;',
#  'the weak things of the world to confound the things',
#  'which god ordained before the world unto our glory: 2:8',
#  'of the princes of this world knew: for had they',
#  'for the wisdom of this world is foolishness with god.',
#  'the world? and if the world shall be judged by',
#  'for the fashion of this world passeth away.  7:32',
#  'eat no flesh while the world standeth, lest i make',
#  'whom the ends of the world are come.  10:12',
#  'whom the god of this world hath blinded the minds',
#  'was in christ, reconciling the world unto himself, not imputing',
#  'but the sorrow of the world worketh death.  7:11',
#  'jesus christ, by whom the world is crucified unto me,',
#  'from the beginning of the world hath been hid in',
#  'christ jesus throughout all ages, world without end. amen. ',
#  'christ jesus came into the world to save sinners; of',
#  'in christ jesus before the world began, 1:10 but is',
#  'cannot lie, promised before the world began; 1:3 but hath',
#  'not put in subjection the world to come, whereof we',
#  'and the powers of the world to come, 6:6 if',
#  'in the end of the world hath he appeared to',
#  'tormented; 11:38 (of whom the world was not worthy:) they',
#  'chosen the poor of this world rich in faith, and',
#  'tongue is a fire, a world of iniquity: so is',
#  'that the friendship of the world is enmity with god?',
#  'be a friend of the world is the enemy of',
#  'corruption that is in the world through lust.  1:5',
#  'in the flood upon the world of the ungodly; 2:6',
#  'escaped the pollutions of the world through the knowledge of',
#  'the water: 3:6 whereby the world that then was, being',
#  'world.  2:17 and the world passeth away, and the',
#  'sons of god: therefore the world knoweth us not, because',
#  'not, my brethren, if the world hate you.  3:14',
#  'of the world, and the world heareth them.  4:6',
#  'of god, and the whole world lieth in wickedness. ',
#  'saying, the kingdoms of this world are become the kingdoms',
#  'was healed: and all the world wondered after the beast.']

# %%
# let's see how many instances of just the word "world" were found
len(concordance)
# Out:
# 113

# %% [markdown]
# Now, in the cell below, modify the code to search for a different word.

# %%
# add your modified code here and run the cell...
concordance = []
for i, val in enumerate(bible):
    if val == "god":
        concordance.append(str(' '.join(bible[i-5:i+5])))

# %%
concordance
# Out:
# [' 1:1 in the beginning god created the heaven and',
#  'deep. and the spirit of god moved upon the face',
#  'the waters.  1:3 and god said, let there be',
#  'was light.  1:4 and god saw the light, that',
#  'that it was good: and god divided the light from',
#  'the darkness.  1:5 and god called the light day,',
#  'first day.  1:6 and god said, let there be',
#  'the waters.  1:7 and god made the firmament, and',
#  'was so.  1:8 and god called the firmament heaven.',
#  'second day.  1:9 and god said, let the waters',
#  'was so.  1:10 and god called the dry land',
#  'waters called he seas: and god saw that it was',
#  'was good.  1:11 and god said, let the earth',
#  'itself, after his kind: and god saw that it was',
#  'third day.  1:14 and god said, let there be',
#  'was so.  1:16 and god made two great lights;',
#  'stars also.  1:17 and god set them in the',
#  'light from the darkness: and god saw that it was',
#  'fourth day.  1:20 and god said, let the waters',
#  'of heaven.  1:21 and god created great whales, and',
#  'fowl after his kind: and god saw that it was',
#  'was good.  1:22 and god blessed them, saying, be',
#  'fifth day.  1:24 and god said, let the earth',
#  'was so.  1:25 and god made the beast of',
#  'earth after his kind: and god saw that it was',
#  'was good.  1:26 and god said, let us make',
#  'the earth.  1:27 so god created man in his',
#  'image, in the image of god created he him; male',
#  'he them.  1:28 and god blessed them, and god',
#  'and god blessed them, and god said unto them, be',
#  'the earth.  1:29 and god said, behold, i have',
#  'was so.  1:31 and god saw every thing that',
#  'and on the seventh day god ended his work which',
#  'had made.  2:3 and god blessed the seventh day,',
#  'from all his work which god created and made. ',
#  'the day that the lord god made the earth and',
#  'it grew: for the lord god had not caused it',
#  ' 2:7 and the lord god formed man of the',
#  ' 2:8 and the lord god planted a garden eastward',
#  'the ground made the lord god to grow every tree',
#  ' 2:15 and the lord god took the man, and',
#  ' 2:16 and the lord god commanded the man, saying,',
#  ' 2:18 and the lord god said, it is not',
#  'of the ground the lord god formed every beast of',
#  ' 2:21 and the lord god caused a deep sleep',
#  'the rib, which the lord god had taken from man,',
#  'the field which the lord god had made. and he',
#  'unto the woman, yea, hath god said, ye shall not',
#  'the midst of the garden, god hath said, ye shall',
#  'not surely die: 3:5 for god doth know that in',
#  'the voice of the lord god walking in the garden',
#  'the presence of the lord god amongst the trees of',
#  ' 3:9 and the lord god called unto adam, and',
#  ' 3:13 and the lord god said unto the woman,',
#  ' 3:14 and the lord god said unto the serpent,',
#  'his wife did the lord god make coats of skins,',
#  ' 3:22 and the lord god said, behold, the man',
#  'ever: 3:23 therefore the lord god sent him forth from',
#  'adam. in the day that god created man, in the',
#  'man, in the likeness of god made he him; 5:2',
#  '5:22 and enoch walked with god after he begat methuselah',
#  'and he was not; for god took him.  5:25',
#  '6:2 that the sons of god saw the daughters of',
#  'that, when the sons of god came in unto the',
#  'of renown.  6:5 and god saw that the wickedness',
#  'with violence.  6:12 and god looked upon the earth,',
#  'the earth.  6:13 and god said unto noah, the',
#  'noah; according to all that god commanded him, so did',
#  'male and the female, as god had commanded noah. ',
#  'female of all flesh, as god had commanded him: and',
#  'fifty days.  8:1 and god remembered noah, and every',
#  'him in the ark: and god made a wind to',
#  'earth dried.  8:15 and god spake unto noah, saying,',
#  'not cease.  9:1 and god blessed noah and his',
#  'for in the image of god made he man. ',
#  'multiply therein.  9:8 and god spake unto noah, and',
#  'the earth.  9:12 and god said, this is the',
#  'remember the everlasting covenant between god and every living creature',
#  'the earth.  9:17 and god said unto noah, this',
#  'said, blessed be the lord god of shem; and canaan',
#  'be his servant.  9:27 god shall enlarge japheth, and',
#  'that spake unto her, thou god seest me: for she',
#  'fell on his face: and god talked with him, saying,',
#  'everlasting covenant, to be a god unto thee, and to',
#  'their god.  17:9 and god said unto abraham, thou',
#  'my covenant.  17:15 and god said unto abraham, as',
#  'before thee!  17:19 and god said, sarah thy wife',
#  'off talking with him, and god went up from abraham.',
#  'in the selfsame day, as god had said unto him.',
#  'it came to pass, when god destroyed the cities of',
#  'cities of the plain, that god remembered abraham, and sent',
#  'took sarah.  20:3 but god came to abimelech in',
#  'done this.  20:6 and god said unto him in',
#  'thought, surely the fear of god is not in this',
#  'it came to pass, when god caused me to wander',
#  'abraham prayed unto god: and god healed abimelech, and his',
#  'the set time of which god had spoken to him.',
#  'being eight days old, as god had commanded him. ',
#  ' 21:6 and sarah said, god hath made me to',
#  'his son.  21:12 and god said unto abraham, let',
#  'and wept.  21:17 and god heard the voice of',
#  'lad; and the angel of god called to hagar out',
#  'thee, hagar? fear not; for god hath heard the voice',
#  'great nation.  21:19 and god opened her eyes, and',
#  'lad drink.  21:20 and god was with the lad;',
#  'host spake unto abraham, saying, god is with thee in',
#  'swear unto me here by god that thou wilt not',
#  'pass after these things, that god did tempt abraham, and',
#  'unto the place of which god had told him. ',
#  'and abraham said, my son, god will provide himself a',
#  'came to the place which god had told him of;',
#  'swear by the lord, the god of heaven, and the',
#  'god of heaven, and the god of the earth, that',
#  'again.  24:7 the lord god of heaven, which took',
#  'and he said o lord god of my master abraham,',
#  'said, blessed be the lord god of my master abraham,',
#  'well, and said, o lord god of my master abraham,',
#  'lord, and blessed the lord god of my master abraham,',
#  'the death of abraham, that god blessed his son isaac;',
#  'and said, i am the god of abraham thy father:',
#  'said, because the lord thy god brought it to me.',
#  'lord hath blessed: 27:28 therefore god give thee of the',
#  "mother's brother.  28:3 and god almighty bless thee, and",
#  'thou art a stranger, which god gave unto abraham. ',
#  'and behold the angels of god ascending and descending on',
#  'said, i am the lord god of abraham thy father,',
#  'abraham thy father, and the god of isaac: the land',
#  'vowed a vow, saying, if god will be with me,',
#  ' 30:6 and rachel said, god hath judged me, and',
#  'that night.  30:17 and god hearkened unto leah, and',
#  ' 30:18 and leah said, god hath given me my',
#  ' 30:20 and leah said, god hath endued me with',
#  'name dinah.  30:22 and god remembered rachel, and god',
#  'and god remembered rachel, and god hearkened to her, and',
#  'bare a son; and said, god hath taken away my',
#  'me as before; but the god of my father hath',
#  'my wages ten times; but god suffered him not to',
#  'cattle ringstraked.  31:9 thus god hath taken away the',
#  '31:11 and the angel of god spake unto me in',
#  ' 31:13 i am the god of bethel, where thou',
#  'for all the riches which god hath taken from our',
#  "our children's: now then, whatsoever god hath said unto thee,",
#  'mount gilead.  31:24 and god came to laban the',
#  'do you hurt: but the god of your father spake',
#  'times.  31:42 except the god of my father, the',
#  'god of my father, the god of abraham, and the',
#  'sent me away now empty. god hath seen mine affliction',
#  'man is with us; see, god is witness betwixt me',
#  'for harm.  31:53 the god of abraham, and the',
#  'god of abraham, and the god of nahor, the god',
#  'the god of nahor, the god of their father, judge',
#  'way, and the angels of god met him.  32:2',
#  '32:9 and jacob said, o god of my father abraham,',
#  'of my father abraham, and god of my father isaac,',
#  'prince hast thou power with god and with men, and',
#  'peniel: for i have seen god face to face, and',
#  'he said, the children which god hath graciously given thy',
#  'is brought to thee; because god hath dealt graciously with',
#  'with an harlot? 35:1 and god said unto jacob, arise,',
#  'journeyed: and the terror of god was upon the cities',
#  'the place elbethel: because there god appeared unto him, when',
#  'called allonbachuth.  35:9 and god appeared unto jacob again,',
#  'blessed him.  35:10 and god said unto him, thy',
#  'name israel.  35:11 and god said unto him, i',
#  'said unto him, i am god almighty: be fruitful and',
#  'the land.  35:13 and god went up from him',
#  'name of the place where god spake with him, bethel.',
#  'it is not in me: god shall give pharaoh an',
#  'dream of pharaoh is one: god hath shewed pharaoh what',
#  'have spoken unto pharaoh: what god is about to do',
#  'is established by god, and god will shortly bring it',
#  'in whom the spirit of god is?  41:39 and',
#  'said unto joseph, forasmuch as god hath shewed thee all',
#  'second called he ephraim: for god hath caused me to',
#  'another, what is this that god hath done unto us?',
#  'unto the man: 43:14 and god almighty give you mercy',
#  'not: your god, and the god of your father, hath',
#  'unto me? and he said, god be gracious unto thee,',
#  'saith my lord these words? god forbid that thy servants',
#  'how shall we clear ourselves? god hath found out the',
#  ' 44:17 and he said, god forbid that i should',
#  'ye sold me hither: for god did send me before',
#  'nor harvest.  45:7 and god sent me before you',
#  'thus saith thy son joseph, god hath made me lord',
#  'and offered sacrifices unto the god of his father isaac.',
#  'father isaac.  46:2 and god spake unto israel in',
#  'said, i am god, the god of thy father: fear',
#  'and jacob said unto joseph, god almighty appeared unto me',
#  'they are my sons, whom god hath given me in',
#  'see thy face: and, lo, god hath shewed me also',
#  'and isaac did walk, the god which fed me all',
#  'thee shall israel bless, saying, god make thee as ephraim',
#  'joseph, behold, i die: but god shall be with you,',
#  'the hands of the mighty god of jacob; (from thence',
#  'israel:) 49:25 even by the god of thy father, who',
#  'of the servants of the god of thy father. and',
#  'thought evil against me; but god meant it unto good,',
#  'his brethren, i die: and god will surely visit you,',
#  'the children of israel, saying, god will surely visit you,',
#  'unto them.  1:20 therefore god dealt well with the',
#  'their cry came up unto god by reason of the',
#  'the bondage.  2:24 and god heard their groaning, and',
#  'god heard their groaning, and god remembered his covenant with',
#  'with jacob.  2:25 and god looked upon the children',
#  'the children of israel, and god had respect unto them.',
#  'he turned aside to see, god called unto him out',
#  'he said, i am the god of thy father, the',
#  'god of thy father, the god of abraham, the god',
#  'the god of abraham, the god of isaac, and the',
#  'god of isaac, and the god of jacob. and moses',
#  'of egypt, ye shall serve god upon this mountain. ',
#  'shall say unto them, the god of your fathers hath',
#  'unto them?  3:14 and god said unto moses, i',
#  'unto you.  3:15 and god said moreover unto moses,',
#  'children of israel, the lord god of your fathers, the',
#  'god of your fathers, the god of abraham, the god',
#  'the god of abraham, the god of isaac, and the',
#  'god of isaac, and the god of jacob, hath sent',
#  'say unto them, the lord god of your fathers, the',
#  'god of your fathers, the god of abraham, of isaac,',
#  'say unto him, the lord god of the hebrews hath',
#  'may believe that the lord god of their fathers, the',
#  'god of their fathers, the god of abraham, the god',
#  'the god of abraham, the god of isaac, and the',
#  'god of isaac, and the god of jacob, hath appeared',
#  'moses took the rod of god in his hand. ',
#  'pharaoh, thus saith the lord god of israel, let my',
#  '5:3 and they said, the god of the hebrews hath',
#  'his land.  6:2 and god spake unto moses, and',
#  'jacob, by the name of god almighty, but by my',
#  'i have made thee a god to pharaoh: and aaron',
#  'say unto him, the lord god of the hebrews hath',
#  'go ye, sacrifice to your god in the land. ',
#  'sacrifice to the lord your god in the wilderness; only',
#  'him, thus saith the lord god of the hebrews, let',
#  'him, thus saith the lord god of the hebrews, let',
#  'him, thus saith the lord god of the hebrews, how',
#  'let the people go, that god led them not through',
#  'although that was near; for god said, lest peradventure the',
#  'return to egypt: 13:18 but god led the people about,',
#  'the children of israel, saying, god will surely visit you;',
#  'said unto them, would to god we had died by',
#  'hill with the rod of god in mine hand. ',
#  'law, heard of all that god had done for moses,',
#  'other was eliezer; for the god of my father, said',
#  'will give thee counsel, and god shall be with thee:',
#  'shalt do this thing, and god command thee so, then',
#  'and louder, moses spake, and god answered him by a',
#  'unto them.  20:1 and god spake all these words,',
#  'for i the lord thy god am a jealous god,',
#  'name of the lord thy god in vain; for the',
#  'land which the lord thy god giveth thee.  20:13',
#  'will hear: but let not god speak with us, lest',
#  'the people, fear not: for god is come to prove',
#  'unto the thick darkness where god was.  20:22 and',
#  'lie not in wait, but god deliver him into his',
#  '24:10 and they saw the god of israel: and there',
#  'them, thus saith the lord god of israel, put every',
#  'before the lord god, the god of israel.  34:24',
#  'appear before the lord thy god thrice in the year.',
#  'of the covenant of thy god to be lacking from',
#  'commandments of the lord his god concerning things which should',
#  'it is most holy, and god hath given it you',
#  'for i the lord your god am holy.  19:3',
#  'the anointing oil of his god is upon him: i',
#  'offer the bread of your god of any of these;',
#  'rejoice before the lord your god seven days.  23:41',
#  'israel, saying, whosoever curseth his god shall bear his sin.',
#  'because the consecration of his god is upon his head.',
#  "thou for my sake? would god that all the lord's",
#  'congregation said unto them, would god that we had died',
#  'land of egypt! or would god we had died in',
#  'thing unto you, that the god of israel hath separated',
#  'and said, o god, the god of the spirits of',
#  'moses, and spake, saying, would god that we had died',
#  'with balaam.  22:9 and god came unto balaam, and',
#  'them out.  22:12 and god said unto balaam, thou',
#  'me more.  22:20 and god came unto balaam at',
#  'any thing? the word that god putteth in my mouth,',
#  'high place.  23:4 and god met balaam: and he',
#  'how shall i curse, whom god hath not cursed? or',
#  'thou son of zippor: 23:19 god is not a man,',
#  'in israel: the lord his god is with him, and',
#  'is among them.  23:22 god brought them out of',
#  'and of israel, what hath god wrought!  23:24 behold,',
#  'place; peradventure it will please god that thou mayest curse',
#  'tribes; and the spirit of god came upon him. ',
#  'shall be exalted.  24:8 god brought him forth out',
#  'alas, who shall live when god doeth this!  24:24',
#  '27:16 let the lord, the god of the spirits of',
#  'saying, 1:6 the lord our god spake unto us in',
#  'alone: 1:10 the lord your god hath multiplied you, and,',
#  'multitude.  1:11 (the lord god of your fathers make',
#  'amorites, as the lord our god commanded us; and we',
#  'amorites, which the lord our god doth give unto us.',
#  '1:21 behold, the lord thy god hath set the land',
#  'possess it, as the lord god of thy fathers hath',
#  'land which the lord our god doth give us. ',
#  ' 1:30 the lord your god which goeth before you,',
#  'how that the lord thy god bare thee, as a',
#  'all that the lord our god commanded us.  and',
#  '2:7 for the lord thy god hath blessed thee in',
#  'forty years the lord thy god hath been with thee;',
#  'land which the lord our god giveth us.  2:30',
#  'him: for the lord thy god hardened his spirit, and',
#  '2:33 and the lord our god delivered him before us;',
#  'for us: the lord our god delivered all unto us:',
#  'unto whatsoever the lord our god forbad us.  3:1',
#  '3:3 so the lord our god delivered into our hands',
#  'time, saying, the lord your god hath given you this',
#  'land which the lord your god hath given them beyond',
#  'all that the lord your god hath done unto these',
#  'them: for the lord your god he shall fight for',
#  'thy mighty hand: for what god is there in heaven',
#  'the land which the lord god of your fathers giveth',
#  'commandments of the lord your god which i command you.',
#  'followed baalpeor, the lord thy god hath destroyed them from',
#  'cleave unto the lord your god are alive every one',
#  'even as the lord my god commanded me, that ye',
#  'there so great, who hath god so nigh unto them,',
#  'them, as the lord our god is in all things',
#  'stoodest before the lord thy god in horeb, when the',
#  'them, which the lord thy god hath divided unto all',
#  'land, which the lord thy god giveth thee for an',
#  'thing, which the lord thy god hath forbidden thee. ',
#  '4:24 for the lord thy god is a consuming fire,',
#  '4:31 (for the lord thy god is a merciful god;)',
#  'thee, since the day that god created man upon the',
#  'people hear the voice of god speaking out of the',
#  'live?  4:34 or hath god assayed to go and',
#  'all that the lord your god did for you in',
#  'that the lord he is god in heaven above, and',
#  'earth, which the lord thy god giveth thee, for ever.',
#  ' 5:2 the lord our god made a covenant with',
#  'for i the lord thy god am a jealous god,',
#  'name of the lord thy god in vain: for the',
#  'it, as the lord thy god hath commanded thee. ',
#  'and that the lord thy god brought thee out thence',
#  'arm: therefore the lord thy god commanded thee to keep',
#  'mother, as the lord thy god hath commanded thee; that',
#  'land which the lord thy god giveth thee.  5:17',
#  'said, behold, the lord our god hath shewed us his',
#  'have seen this day that god doth talk with man,',
#  'voice of the lord our god any more, then we',
#  'the voice of the living god speaking out of the',
#  'all that the lord our god shall say: and speak',
#  'all that the lord our god shall speak unto thee;',
#  'therefore as the lord your god hath commanded you: ye',
#  'ways which the lord your god hath commanded you, that',
#  'judgments, which the lord your god commanded to teach you,',
#  'increase mightily, as the lord god of thy fathers hath',
#  'o israel: the lord our god is one lord: 6:5',
#  'shalt love the lord thy god with all thine heart,',
#  'be, when the lord thy god shall have brought thee',
#  '6:15 (for the lord thy god is a jealous god',
#  'thy god is a jealous god among you) lest the',
#  'anger of the lord thy god be kindled against thee,',
#  'judgments, which the lord our god hath commanded you? ',
#  '7:1 when the lord thy god shall bring thee into',
#  'and when the lord thy god shall deliver them before',
#  'thy god: the lord thy god hath chosen thee to',
#  'them, that the lord thy god shall keep unto thee',
#  'people which the lord thy god shall deliver thee; thine',
#  'remember what the lord thy god did unto pharaoh, and',
#  'arm, whereby the lord thy god brought thee out: so',
#  'so shall the lord thy god do unto all the',
#  '7:20 moreover the lord thy god will send the hornet',
#  'them: for the lord thy god is among you, a',
#  'is among you, a mighty god and terrible.  7:22',
#  '7:22 and the lord thy god will put out those',
#  '7:23 but the lord thy god shall deliver them unto',
#  'way which the lord thy god led thee these forty',
#  'son, so the lord thy god chasteneth thee.  8:6',
#  '8:7 for the lord thy god bringeth thee into a',
#  'shalt bless the lord thy god for the good land',
#  'day, that the lord thy god is he which goeth',
#  'after that the lord thy god hath cast them out',
#  'these nations the lord thy god doth drive them out',
#  'therefore, that the lord thy god giveth thee not this',
#  'thou provokedst the lord thy god to wrath in the',
#  'according as the lord thy god promised him.  10:10',
#  'what doth the lord thy god require of thee, but',
#  'to serve the lord thy god with all thy heart',
#  '10:17 for the lord your god is god of gods,',
#  'the lord your god is god of gods, and lord',
#  'and now the lord thy god hath made thee as',
#  'land which the lord thy god careth for: the eyes',
#  'eyes of the lord thy god are always upon it,',
#  'you: for the lord your god shall lay the fear',
#  'pass, when the lord thy god hath brought thee in',
#  'land which the lord your god giveth you, and ye',
#  'the land, which the lord god of thy fathers giveth',
#  'place which the lord your god shall choose out of',
#  'households, wherein the lord thy god hath blessed thee. ',
#  'inheritance, which the lord your god giveth you.  12:10',
#  'land which the lord your god giveth you to inherit,',
#  'place which the lord your god shall choose to cause',
#  'blessing of the lord thy god which he hath given',
#  'them before the lord thy god in the place which',
#  'place which the lord thy god shall choose, thou, and',
#  'rejoice before the lord thy god in all that thou',
#  '12:20 when the lord thy god shall enlarge thy border,',
#  'place which the lord thy god hath chosen to put',
#  '12:29 when the lord thy god shall cut off the',
#  'dreams: for the lord your god proveth you, to know',
#  'ye love the lord your god with all your heart',
#  'way which the lord thy god commanded thee to walk',
#  'cities, which the lord thy god hath given thee to',
#  'to fear the lord thy god always.  14:24 and',
#  'thee, which the lord thy god shall choose to set',
#  'there, when the lord thy god hath blessed thee: 14:25',
#  'place which the lord thy god shall choose: 14:26 and',
#  'satisfied; that the lord thy god may bless thee in',
#  'land which the lord thy god giveth thee for an',
#  '15:6 for the lord thy god blesseth thee, as he',
#  'land which the lord thy god giveth thee, thou shalt',
#  'this thing the lord thy god shall bless thee in',
#  'that wherewith the lord thy god hath blessed thee thou',
#  'egypt, and the lord thy god redeemed thee: therefore i',
#  'years: and the lord thy god shall bless thee in',
#  'it before the lord thy god year by year in',
#  'of abib the lord thy god brought thee forth out',
#  'gates, which the lord thy god giveth thee: 16:6 but',
#  'place which the lord thy god shall choose to place',
#  'place which the lord thy god shall choose: and thou',
#  'weeks unto the lord thy god with a tribute of',
#  'according as the lord thy god hath blessed thee: 16:11',
#  'place which the lord thy god hath chosen to place',
#  'feast unto the lord thy god in the place which',
#  'choose: because the lord thy god shall bless thee in',
#  'appear before the lord thy god in the place which',
#  'blessing of the lord thy god which he hath given',
#  'gates, which the lord thy god giveth thee, throughout thy',
#  'land which the lord thy god giveth thee.  16:21',
#  'image; which the lord thy god hateth.  17:1 thou',
#  'sacrifice unto the lord thy god any bullock, or sheep,',
#  'gates which the lord thy god giveth thee, man or',
#  'place which the lord thy god shall choose; 17:9 and',
#  'land which the lord thy god giveth thee, and shalt',
#  'thee, whom the lord thy god shall choose: one from',
#  '18:5 for the lord thy god hath chosen him out',
#  'land which the lord thy god giveth thee, thou shalt',
#  'these abominations the lord thy god doth drive them out',
#  'for thee, the lord thy god hath not suffered thee',
#  ' 18:15 the lord thy god will raise up unto',
#  'desiredst of the lord thy god in horeb in the',
#  '19:1 when the lord thy god hath cut off the',
#  'whose land the lord thy god giveth thee, and thou',
#  'land, which the lord thy god giveth thee to possess',
#  'land, which the lord thy god giveth thee to inherit,',
#  'and if the lord thy god enlarge thy coast, as',
#  'land, which the lord thy god giveth thee for an',
#  'land that the lord thy god giveth thee to possess',
#  'them: for the lord thy god is with thee, which',
#  '20:4 for the lord your god is he that goeth',
#  'and when the lord thy god hath delivered it into',
#  'enemies, which the lord thy god hath given thee. ',
#  'people, which the lord thy god doth give thee for',
#  'jebusites; as the lord thy god hath commanded thee: 20:18',
#  'land which the lord thy god giveth thee to possess',
#  'for them the lord thy god hath chosen to minister',
#  'enemies, and the lord thy god hath delivered them into',
#  'defiled, which the lord thy god giveth thee for an',
#  '23:5 nevertheless the lord thy god would not hearken unto',
#  'balaam; but the lord thy god turned the curse into',
#  'thee, because the lord thy god loved thee.  23:6',
#  '23:14 for the lord thy god walketh in the midst',
#  'house of the lord thy god for any vow: for',
#  'usury: that the lord thy god may bless thee in',
#  'it: for the lord thy god will surely require it',
#  'sin, which the lord thy god giveth thee for an',
#  'remember what the lord thy god did unto miriam by',
#  'egypt, and the lord thy god redeemed thee thence: therefore',
#  'widow: that the lord thy god may bless thee in',
#  'land which the lord thy god giveth thee.  25:16',
#  'be, when the lord thy god hath given thee rest',
#  'land which the lord thy god giveth thee for an',
#  'land which the lord thy god giveth thee for an',
#  'land that the lord thy god giveth thee, and shalt',
#  'place which the lord thy god shall choose to place',
#  'we cried unto the lord god of our fathers, the',
#  'thing which the lord thy god hath given unto thee,',
#  'this day the lord thy god hath commanded thee to',
#  'land which the lord thy god giveth thee, that thou',
#  'land which the lord thy god giveth thee, a land',
#  'and honey; as the lord god of thy fathers hath',
#  'altar of the lord thy god of whole stones: and',
#  'day, that the lord thy god will set thee on',
#  'land which the lord thy god giveth thee.  28:9',
#  'servedst not the lord thy god with joyfulness, and with',
#  'land, which the lord thy god hath given thee. ',
#  'daughters, which the lord thy god hath given thee, in',
#  'morning thou shalt say, would god it were even! and',
#  'even thou shalt say, would god it were morning! for',
#  'oath, which the lord thy god maketh with thee this',
#  'the covenant of the lord god of their fathers, which',
#  'nations, whither the lord thy god hath driven thee, 30:2',
#  'that then the lord thy god will turn thy captivity,',
#  'nations, whither the lord thy god hath scattered thee. ',
#  'thence will the lord thy god gather thee, and from',
#  '30:5 and the lord thy god will bring thee into',
#  '30:6 and the lord thy god will circumcise thine heart,',
#  'to love the lord thy god with all thine heart,',
#  '30:7 and the lord thy god will put all these',
#  '30:9 and the lord thy god will make thee plenteous',
#  'turn unto the lord thy god with all thine heart,',
#  'multiply: and the lord thy god shall bless thee in',
#  'appear before the lord thy god in the place which',
#  'come upon us, because our god is not among us?',
#  'his ways are judgment: a god of truth and without',
#  'and there was no strange god with him.  32:13',
#  'with fatness; then he forsook god which made him, and',
#  'art unmindful, and hast forgotten god that formed thee. ',
#  'he, and there is no god with me: i kill,',
#  'wherewith moses the man of god blessed the children of',
#  'is none like unto the god of jeshurun, who rideth',
#  'sky.  33:27 the eternal god is thy refuge, and',
#  'dismayed: for the lord thy god is with thee whithersoever',
#  'land, which the lord your god giveth you to possess',
#  'you, saying, the lord your god hath given you rest,',
#  'land which the lord your god giveth them: then ye',
#  'thee: only the lord thy god be with thee, as',
#  'lord your god, he is god in heaven above, and',
#  'shall know that the living god is among you, and',
#  'ark of the lord your god into the midst of',
#  '4:23 for the lord your god dried up the waters',
#  'over, as the lord your god did to the red',
#  'might fear the lord your god for ever.  5:1',
#  'to destroy us? would to god we had been content,',
#  'for thus saith the lord god of israel, there is',
#  'thee, glory to the lord god of israel, and make',
#  'have sinned against the lord god of israel, and thus',
#  'city: for the lord your god will deliver it into',
#  'an altar unto the lord god of israel in mount',
#  'unto them by the lord god of israel. and all',
#  'unto them by the lord god of israel: now therefore',
#  'how that the lord thy god commanded his servant moses',
#  'cities: for the lord your god hath delivered them into',
#  'that breathed, as the lord god of israel commanded. ',
#  'one time, because the lord god of israel fought for',
#  'the sacrifices of the lord god of israel made by',
#  'not any inheritance: the lord god of israel was their',
#  'unto moses the man of god concerning me and thee',
#  'he wholly followed the lord god of israel.  14:15',
#  'the land, which the lord god of your fathers hath',
#  'and now the lord your god hath given rest unto',
#  'ye have committed against the god of israel, to turn',
#  'of israel, 22:22 the lord god of gods, the lord',
#  'god of gods, the lord god of gods, he knoweth,',
#  'to do with the lord god of israel?  22:25',
#  'us and you.  22:29 god forbid that we should',
#  'altar of the lord our god that is before his',
#  'all that the lord your god hath done unto all',
#  'you; for the lord your god is he that hath',
#  'land, as the lord your god hath promised unto you.',
#  'certainty that the lord your god will no more drive',
#  'land which the lord your god hath given you. ',
#  'things which the lord your god spake concerning you; all',
#  'you, which the lord your god promised you; so shall',
#  'land which the lord your god hath given you. ',
#  'people, thus saith the lord god of israel, your fathers',
#  'the people answered and said, god forbid that we should',
#  'your heart unto the lord god of israel.  24:24',
#  'unto joshua, the lord our god will we serve, and',
#  'as i have done, so god hath requited me. and',
#  'and they forsook the lord god of their fathers, which',
#  'i have a message from god unto thee.  and',
#  'him, hath not the lord god of israel commanded, saying,',
#  'his temples.  4:23 so god subdued on that day',
#  'sing praise to the lord god of israel.  5:4',
#  'sinai from before the lord god of israel.  5:6',
#  'them, thus saith the lord god of israel, i brought',
#  '6:20 and the angel of god said unto him, take',
#  'altar unto the lord thy god upon the top of',
#  'be dew.  6:40 and god did so that night:',
#  'for into his hand hath god delivered midian, and all',
#  'vintage of abiezer?  8:3 god hath delivered into your',
#  'ye men of shechem, that god may hearken unto you.',
#  'wherewith by me they honour god and man, and go',
#  'leave my wine, which cheereth god and man, and go',
#  'years over israel, 9:23 then god sent an evil spirit',
#  ' 9:29 and would to god this people were under',
#  'of the house of the god berith.  9:47 and',
#  'his place.  9:56 thus god rendered the wickedness of',
#  'the men of shechem did god render upon their heads:',
#  ' 11:21 and the lord god of israel delivered sihon',
#  '11:23 so now the lord god of israel hath dispossessed',
#  'possess that which chemosh thy god giveth thee to possess?',
#  'so whomsoever the lord our god shall drive out from',
#  'shall be a nazarite unto god from the womb: and',
#  'husband, saying, a man of god came unto me, and',
#  'shall be a nazarite to god from the womb to',
#  'lord, let the man of god which thou didst send',
#  'be born.  13:9 and god hearkened to the voice',
#  'manoah; and the angel of god came again unto the',
#  'the uncircumcised?  15:19 but god clave an hollow place',
#  "have been a nazarite unto god from my mother's womb:",
#  'rejoice: for they said, our god hath delivered samson our',
#  'god: for they said, our god hath delivered into our',
#  'to a large land: for god hath given it into',
#  'time that the house of god was in shiloh. ',
#  'ark of the covenant of god was there in those',
#  '21:3 and said, o lord god of israel, why is',
#  'be my people, and thy god my god: 1:17 where',
#  'given thee of the lord god of israel, under whose',
#  'go in peace: and the god of israel grant thee',
#  'for the lord is a god of knowledge, and by',
#  'there came a man of god unto eli, and said',
#  ' 2:30 wherefore the lord god of israel saith, i',
#  'in all the wealth which god shall give israel: and',
#  'and ere the lamp of god went out in the',
#  'lord, where the ark of god was, and samuel was',
#  'hide it not from me: god do so to thee,',
#  'were afraid, for they said, god is come into the',
#  '4:11 and the ark of god was taken; and the',
#  'dead, and the ark of god is taken.  4:18',
#  'tidings that the ark of god was taken, and that',
#  'israel: because the ark of god was taken, and because',
#  'israel: for the ark of god is taken.  5:1',
#  'said, the ark of the god of israel shall not',
#  'with the ark of the god of israel? and they',
#  'let the ark of the god of israel be carried',
#  'carried the ark of the god of israel about thither.',
#  'they sent the ark of god to ekron. and it',
#  'pass, as the ark of god came to ekron, that',
#  'about the ark of the god of israel to us,',
#  'away the ark of the god of israel, and let',
#  'the city; the hand of god was very heavy there.',
#  'away the ark of the god of israel, send it',
#  'shall give glory unto the god of israel: peradventure he',
#  'cry unto the lord our god for us, that he',
#  'city where the man of god was.  9:11 and',
#  'three men going up to god to bethel, one carrying',
#  'as occasion serve thee; for god is with thee. ',
#  'back to go from samuel, god gave him another heart:',
#  'him; and the spirit of god came upon him, and',
#  'israel, thus saith the lord god of israel, i brought',
#  'the people shouted, and said, god save the king. ',
#  'band of men, whose hearts god had touched.  10:27',
#  '11:6 and the spirit of god came upon saul when',
#  'us: when the lord your god was your king. ',
#  '12:23 moreover as for me, god forbid that i should',
#  'god. for the ark of god was at that time',
#  'saul said unto the lord god of israel, give a',
#  ' 14:44 and saul answered, god do so and more',
#  'this great salvation in israel? god forbid: as the lord',
#  'for he hath wrought with god this day. so the',
#  'sacrifice unto the lord thy god in gilgal.  15:22',
#  'now, an evil spirit from god troubleth thee.  16:16',
#  'when the evil spirit from god is upon thee, that',
#  'when the evil spirit from god was upon saul, that',
#  'the lord of hosts, the god of the armies of',
#  'know that there is a god in israel.  17:47',
#  'that the evil spirit from god came upon saul, and',
#  'over them, the spirit of god was upon the messengers',
#  'ramah: and the spirit of god was upon him also,',
#  'and he said unto him, god forbid; thou shalt not',
#  'said unto david, o lord god of israel, when i',
#  'you, till i know what god will do for me.',
#  'sword, and hast enquired of god for him, that he',
#  'then begin to enquire of god for him? be it',
#  'to keilah. and saul said, god hath delivered him into',
#  'then said david, o lord god of israel, thy servant',
#  'servant hath heard? o lord god of israel, i beseech',
#  'sought him every day, but god delivered him not into',
#  'so and more also do god unto the enemies of',
#  'abigail, blessed be the lord god of israel, which sent',
#  'very deed, as the lord god of israel liveth, which',
#  'then said abishai to david, god hath delivered thine enemy',
#  'make war against me, and god is departed from me,',
#  '2:27 and joab said, as god liveth, unless thou hadst',
#  'woman?  3:9 so do god to abner, and more',
#  'david sware, saying, so do god to me, and more',
#  'grew great, and the lord god of hosts was with',
#  'they set the ark of god upon a new cart,',
#  'was kindled against uzzah; and god smote him there for',
#  'brought up the ark of god from the house of',
#  'cedar, but the ark of god dwelleth within curtains. ',
#  'thee, neither is there any god beside thee, according to',
#  'people, even like israel, whom god went to redeem for',
#  'lord of hosts is the god over israel: and let',
#  'thou, o lord of hosts, god of israel, hast revealed',
#  'may shew the kindness of god unto him? and ziba',
#  'man. thus saith the lord god of israel, i anointed',
#  ' 12:16 david therefore besought god for the child; and',
#  'said, who can tell whether god will be gracious to',
#  'gathered up again; neither doth god respect any person: yet',
#  'bad: therefore the lord thy god will be with thee.',
#  'carry back the ark of god into the city: if',
#  'abiathar carried the ark of god again to jerusalem: and',
#  'that hushai said unto absalom, god save the king, god',
#  'absalom, god save the king, god save the king. ',
#  'son, my son absalom! would god i had died for',
#  'bone, and of my flesh? god do so to me,',
#  'king commanded. and after that god was intreated for the',
#  'and my deliverer; 22:3 the god of my rock; in',
#  'through a troop: by my god have i leaped over',
#  'rock, save our god? 22:33 god is my strength and',
#  'rock; and exalted be the god of the rock of',
#  'salvation.  22:48 it is god that avengeth me, and',
#  'high, the anointed of the god of jacob, and the',
#  'my tongue.  23:3 the god of israel said, the',
#  'king, now the lord thy god add unto the people,',
#  'the king, the lord thy god accept thee.  24:24',
#  'offerings unto the lord my god of that which doth',
#  'swarest by the lord thy god unto thine handmaid, saying,',
#  'drink before him, and say, god save king adonijah. ',
#  'unto thee by the lord god of israel, saying, assuredly',
#  'with the trumpet, and say, god save king solomon. ',
#  'and said, amen: the lord god of my lord the',
#  'and all the people said, god save king solomon. ',
#  'our lord king david, saying, god make the name of',
#  'king, blessed be the lord god of israel, which hath',
#  'sware by the lord, saying, god do so to me,',
#  'the ark of the lord god before david my father,',
#  'a dream by night: and god said, ask what i',
#  'this thing.  3:11 and god said unto him, because',
#  'saw that the wisdom of god was in him, to',
#  'his charge.  4:29 and god gave solomon wisdom and',
#  'name of the lord his god for the wars which',
#  'but now the lord my god hath given me rest',
#  'said, blessed be the lord god of israel, which spake',
#  'the name of the lord god of israel.  8:18',
#  'the name of the lord god of israel.  8:21',
#  '8:23 and he said, lord god of israel, there is',
#  'of israel, there is no god like thee, in heaven',
#  ' 8:25 therefore now, lord god of israel, keep with',
#  ' 8:26 and now, o god of israel, let thy',
#  'father.  8:27 but will god indeed dwell on the',
#  ' 8:57 the lord our god be with us, as',
#  'nigh unto the lord our god day and night, that',
#  'to hear his wisdom, which god had put in his',
#  'was turned from the lord god of israel, which had',
#  'any wise.  11:23 and god stirred him up another',
#  'thus saith the lord, the god of israel, behold, i',
#  'of the zidonians, chemosh the god of the moabites, and',
#  'the moabites, and milcom the god of the children of',
#  '12:22 but the word of god came unto shemaiah the',
#  'there came a man of god out of judah by',
#  'sign which the man of god had given by the',
#  'again. and the man of god besought the lord, and',
#  '13:8 and the man of god said unto the king,',
#  'works that the man of god had done that day',
#  'what way the man of god went, which came from',
#  'art thou the man of god that camest from judah?',
#  'cried unto the man of god that came from judah,',
#  'commandment which the lord thy god commanded thee, 13:22 but',
#  'sepulchre wherein the man of god is buried; lay my',
#  'jeroboam, thus saith the lord god of israel, forasmuch as',
#  'good thing toward the lord god of israel in the',
#  'sake did the lord his god give him a lamp',
#  'wherewith he provoked the lord god of israel to anger.',
#  'sin, in provoking the lord god of israel to anger',
#  'sin, to provoke the lord god of israel to anger',
#  'more to provoke the lord god of israel to anger',
#  'unto ahab, as the lord god of israel liveth, before',
#  'said, as the lord thy god liveth, i have not',
#  'for thus saith the lord god of israel, the barrel',
#  '18:10 as the lord thy god liveth, there is no',
#  'of the lord: and the god that answereth by fire,',
#  'came near, and said, lord god of abraham, isaac, and',
#  'this day that thou art god in israel, and that',
#  'very jealous for the lord god of hosts: for the',
#  'very jealous for the lord god of hosts: because the',
#  'have said, the lord is god of the hills, but',
#  'hills, but he is not god of the valleys, therefore',
#  'him, saying, thou didst blaspheme god and the king. and',
#  'people, saying, naboth did blaspheme god and the king. then',
#  'provoked to anger the lord god of israel, according to',
#  'go, enquire of baalzebub the god of ekron whether i',
#  'because there is not a god in israel, that ye',
#  'to enquire of baalzebub the god of ekron?  1:4',
#  'because there is not a god in israel, that thou',
#  'to enquire of baalzebub the god of ekron? therefore thou',
#  'fifty. and the fire of god came down from heaven,',
#  'to enquire of baalzebub the god of ekron, is it',
#  'not because there is no god in israel to enquire',
#  'said, where is the lord god of elijah? and when',
#  'came unto the man of god to mount carmel. and',
#  'pass, when the man of god saw her afar off,',
#  'came to the man of god to the hill, she',
#  'away. and the man of god said, let her alone;',
#  'and brought the man of god bread of the firstfruits,',
#  'said unto her mistress, would god my lord were with',
#  'when elisha the man of god had heard that the',
#  'know that there is no god in all the earth,',
#  '6:6 and the man of god said, where fell it?',
#  '6:9 and the man of god sent unto the king',
#  'place which the man of god told him and warned',
#  'servant of the man of god was risen early, and',
#  ' 6:31 then he said, god do so and more',
#  'died, as the man of god had said, who spake',
#  'pass as the man of god had spoken to the',
#  'him, saying, the man of god is come hither. ',
#  'ashamed: and the man of god wept.  8:12 and',
#  'him, thus saith the lord god of israel, i have',
#  'the law of the lord god of israel with all',
#  'clapped their hands, and said, god save the king. ',
#  '13:19 and the man of god was wroth with him,',
#  'the word of the lord god of israel, which he',
#  'not the manner of the god of the land: therefore',
#  'not the manner of the god of the land. ',
#  'them the manner of the god of the land. ',
#  '17:39 but the lord your god ye shall fear; and',
#  'he trusted in the lord god of israel; so that',
#  'may be the lord thy god will hear all the',
#  'words which the lord thy god hath heard: wherefore lift',
#  'judah, saying, let not thy god in whom thou trustest',
#  'lord, and said, o lord god of israel, which dwellest',
#  'saying, thus saith the lord god of israel, that which',
#  'thus saith the lord, the god of david thy father,',
#  'therefore thus saith the lord god of israel, behold, i',
#  'and he forsook the lord god of his fathers, and',
#  'them, thus saith the lord god of israel, tell the',
#  'him, thus saith the lord god of israel, as touching',
#  'lord which the man of god proclaimed, who proclaimed these',
#  'and jabez called on the god of israel, saying, oh',
#  'may not grieve me! and god granted him that which',
#  'them: for they cried to god in the battle, and',
#  'and they transgressed against the god of their fathers, and',
#  'people of the land, whom god destroyed before them. ',
#  'them.  5:26 and the god of israel stirred up',
#  'that moses the servant of god had commanded.  6:50',
#  'israel: and the lord thy god said unto thee, thou',
#  ' 11:19 and said, my god forbid it me, that',
#  'wrong in mine hands, the god of our fathers look',
#  'to thine helpers; for thy god helpeth thee.  then',
#  'again the ark of our god to us: for we',
#  'to bring the ark of god from kirjathjearim.  13:6',
#  'up thence the ark of god the lord, that dwelleth',
#  'they carried the ark of god in a new cart',
#  'and all israel played before god with all their might,',
#  'and david was afraid of god that day, saying, how',
#  'i bring the ark of god home to me? ',
#  '13:14 and the ark of god remained with the family',
#  'them there. then david said, god hath broken in upon',
#  'enquired again of god; and god said unto him, go',
#  'go out to battle: for god is gone forth before',
#  '14:16 david therefore did as god commanded him: and they',
#  'to carry the ark of god but the levites: for',
#  'the ark of the lord god of israel unto the',
#  'the first, the lord our god made a breach upon',
#  'the ark of the lord god of israel.  15:15',
#  'levites bare the ark of god upon their shoulders with',
#  'it came to pass, when god helped the levites that',
#  'thank and praise the lord god of israel: 16:5 asaph',
#  'say ye, save us, o god of our salvation, and',
#  '16:36 blessed be the lord god of israel for ever',
#  'is in thine heart; for god is with thee. ',
#  'night, that the word of god came to nathan, saying,',
#  'thee, neither is there any god beside thee, according to',
#  'like thy people israel, whom god went to redeem to',
#  'lord of hosts is the god of israel, even a',
#  'god of israel, even a god to israel: and let',
#  'to joab.  21:7 and god was displeased with this',
#  'thousand men.  21:15 and god sent an angel unto',
#  'an house for the lord god of israel.  22:7',
#  'is not the lord your god with you? and hath',
#  'for david said, the lord god of israel hath given',
#  'their father, as the lord god of israel had commanded',
#  'lift up the horn. and god gave to heman fourteen',
#  'seventh, peulthai the eighth: for god blessed him.  26:6',
#  'for the building: 28:3 but god said unto me, thou',
#  ' 28:4 howbeit the lord god of israel chose me',
#  'my son, know thou the god of thy father, and',
#  'solomon my son, whom alone god hath chosen, is yet',
#  'for the house of my god the gold for things',
#  'service of the house of god of gold five thousand',
#  'said, blessed be thou, lord god of israel our father,',
#  'thee.  29:18 o lord god of abraham, isaac, and',
#  'the congregation blessed the lord god of their fathers, and',
#  'kingdom, and the lord his god was with him, and',
#  '1:4 but the ark of god had david brought up',
#  '1:7 in that night did god appear unto solomon, and',
#  'so great?  1:11 and god said to solomon, because',
#  'great: for great is our god above all gods. ',
#  'moreover, blessed be the lord god of israel, that made',
#  'said, blessed be the lord god of israel, who hath',
#  'the name of the lord god of israel.  6:8',
#  'the name of the lord god of israel.  6:11',
#  '6:14 and said, o lord god of israel, there is',
#  'of israel, there is no god like thee in the',
#  '6:16 now therefore, o lord god of israel, keep with',
#  '6:17 now then, o lord god of israel, let thy',
#  'david.  6:18 but will god in very deed dwell',
#  'because they forsook the lord god of their fathers, which',
#  'had david the man of god commanded.  8:15 and',
#  'lord thy god: because thy god loved israel, to establish',
#  'to hear his wisdom, that god had put in his',
#  'hearts to seek the lord god of israel came to',
#  'to sacrifice unto the lord god of their fathers. ',
#  'to know that the lord god of israel gave the',
#  'him.  13:12 and, behold, god himself is with us',
#  'ye not against the lord god of your fathers; for',
#  'it came to pass, that god smote jeroboam and all',
#  'israel fled before judah: and god delivered them into their',
#  'they relied upon the lord god of their fathers. ',
#  'judah to seek the lord god of their fathers, and',
#  '15:1 and the spirit of god came upon azariah the',
#  'did turn unto the lord god of israel, and sought',
#  'and city of city: for god did vex them with',
#  'saw that the lord his god was with him. ',
#  'covenant to seek the lord god of their fathers with',
#  'would not seek the lord god of israel should be',
#  'brought into the house of god the things that his',
#  'but sought to the lord god of his father, and',
#  'they said, go up; for god will deliver it into',
#  'lord liveth, even what my god saith, that will i',
#  'the lord helped him; and god moved them to depart',
#  'them back unto the lord god of their fathers. ',
#  '20:6 and said, o lord god of our fathers, art',
#  'our fathers, art not thou god in heaven? and rulest',
#  'up to praise the lord god of israel with a',
#  '20:29 and the fear of god was on all the',
#  'jehoshaphat was quiet: for his god gave him rest round',
#  'prepared their hearts unto the god of their fathers. ',
#  'he had forsaken the lord god of his fathers. ',
#  'saying, thus saith the lord god of david thy father,',
#  'destruction of ahaziah was of god by coming to joram:',
#  'hid in the house of god six years: and athaliah',
#  'sons anointed him, and said, god save the king. ',
#  'repair the house of your god from year to year,',
#  'that moses the servant of god laid upon israel in',
#  'they set the house of god in his state, and',
#  'the house of the lord god of their fathers, and',
#  '24:20 and the spirit of god came upon zechariah the',
#  'they had forsaken the lord god of their fathers. so',
#  'there came a man of god to him, saying, o',
#  'be strong for the battle: god shall make thee fall',
#  'fall before the enemy: for god hath power to help,',
#  'israel? and the man of god answered, the lord is',
#  'and said, i know that god hath determined to destroy',
#  'found in the house of god with obededom, and the',
#  ' 26:5 and he sought god in the days of',
#  'as he sought the lord, god made him to prosper.',
#  'the philistines.  26:7 and god helped him against the',
#  '28:5 wherefore the lord his god delivered him into the',
#  'they had forsaken the lord god of their fathers. ',
#  'them, behold, because the lord god of your fathers was',
#  'provoked to anger the lord god of his fathers. ',
#  'the house of the lord god of your fathers, and',
#  'the holy place unto the god of israel.  29:8',
#  'a covenant with the lord god of israel, that his',
#  'and all the people, that god had prepared the people:',
#  'the passover unto the lord god of israel.  30:2',
#  'the passover unto the lord god of israel at jerusalem:',
#  'turn again unto the lord god of abraham, isaac, and',
#  'which trespassed against the lord god of their fathers, who',
#  'land: for the lord your god is gracious and merciful,',
#  'in judah the hand of god was to give them',
#  'to seek god, the lord god of his fathers, though',
#  'making confession to the lord god of their fathers. ',
#  'us is the lord our god to help us, and',
#  'thirst, saying, the lord our god shall deliver us out',
#  'of mine hand, that your god should be able to',
#  'yet believe him: for no god of any nation or',
#  'how much less shall your god deliver you out of',
#  'to rail on the lord god of israel, and to',
#  'hand, so shall not the god of hezekiah deliver his',
#  'and they spake against the god of jerusalem, as against',
#  'and herds in abundance: for god had given him substance',
#  'was done in the land, god left him, to try',
#  'house of god, of which god had said to david',
#  'humbled himself greatly before the god of his fathers, 33:13',
#  'judah to serve the lord god of israel.  33:17',
#  'yet unto the lord their god only.  33:18 now',
#  'the name of the lord god of israel, behold, they',
#  'his prayer also, and how god was intreated of him,',
#  'began to seek after the god of david his father:',
#  'them, thus saith the lord god of israel, tell ye',
#  'him, thus saith the lord god of israel concerning the',
#  'the covenant of god, the god of their fathers. ',
#  'from following the lord, the god of their fathers. ',
#  'wherewith i have war: for god commanded me to make',
#  'from turning unto the lord god of israel.  36:14',
#  ' 36:15 and the lord god of their fathers sent',
#  'the earth hath the lord god of heaven given me;',
#  'people?  the lord his god be with him, and',
#  'king of persia, the lord god of heaven hath given',
#  'of all his people? his god be with him, and',
#  'the house of the lord god of israel, (he is',
#  'offering for the house of god that is in jerusalem.',
#  'with all them whose spirit god had raised, to go',
#  'freely for the house of god to set it up',
#  'builded the altar of the god of israel, to offer',
#  'coming unto the house of god at jerusalem, in the',
#  'the temple unto the lord god of israel; 4:2 then',
#  'will build unto the lord god of israel, as king',
#  'work of the house of god which is at jerusalem.',
#  'in the name of the god of israel, even unto',
#  'to build the house of god which is at jerusalem:',
#  'them were the prophets of god helping them.  5:3',
#  'but the eye of their god was upon the elders',
#  'are the servants of the god of heaven and earth,',
#  'our fathers had provoked the god of heaven unto wrath,',
#  'and let the house of god be builded in his',
#  'foundation of the house of god which is in jerusalem:',
#  'to build this house of god at jerusalem, and let',
#  'decree concerning the house of god at jerusalem, let the',
#  'work of this house of god alone; let the governor',
#  ...]

# %%
len(concordance)
# Out:
# 2303

# %% [markdown]
# The nltk package has the full text of several other classic books. You can see what they are called by running the command in the cell below:

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# ## Your turn!
#
# Here are a some more things you can try. In each case, I have given you a little bit of starter code to get you going, but the cells will not run without some additional code from you.

# %%
#Setup for challenges
# %pip install nltk
import nltk
nltk.download('gutenberg')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in /home/ucloud/.local/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: click in /usr/lib/python3/dist-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /home/ucloud/.local/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/ucloud/.local/lib/python3.12/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /home/ucloud/.local/lib/python3.12/site-packages (from nltk) (4.66.5)
# Note: you may need to restart the kernel to use updated packages.
# [nltk_data] Downloading package gutenberg to /home/ucloud/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %% [markdown]
# ## Challenge 1: build your own concordance
#
# Pick a different book and a different word, or pair of words. Copy and paste from the code above to write some Python code that searches the book of your choice for the word or pair of words of your choice. Put this code in the cell below. By the way, some of the texts use the characters "\r" for "carriage return" instead of "\n" for "newline". You can remove these the same way that you remove the "\n" characters.

# %%
# add your code to search for a word or pair of words in a different book here

# Create a variable called "paradise" which contains the text of Milton's Paradise Lost.
paradise = nltk.corpus.gutenberg.raw('milton-paradise.txt')

# make all characters lowercase
paradise = paradise.lower()

# remove the "\n" characters, which indicate line breaks in the text (newlines)
paradise = paradise.replace('\n', ' ')

# split up the text into a long list of individual words
paradise = paradise.split(' ')


#Make concordance list, which counts amount of times the word "satan" appears in the book
par_concordance = []
for i, val in enumerate(paradise):
    if val == "satan":
        par_concordance.append(str(' '.join(paradise[i-5:i+5])))


#
len(par_concordance)
# Out:
# 36

# %% [markdown]
# ## Challenge 2: compare lengths of books
#
# We can use the command `len` to find how many items there are in a list. E.g., to find the number of words in the list called `bible`, above, we can write: `len(bible)`.
#
# Use the starter code below to find out which book in the books included in `nltk` has the most words.

# %%
# solution 1: print all the titles and numbers of words
# starter code:

books = nltk.corpus.gutenberg.fileids()

titlelen_book = []
for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    book = book.lower()
    book = book.replace('\n', ' ')
    book = book.split(' ')
    words = len(book)
    print(f'The book {title} has {words} words')
    # titlelen_book.append(title, len(book))

# Create dictionary to store data of both title and length of book

# print(book)
# functional print statement
# Out:
# The book austen-emma.txt has 164457 words
# The book austen-persuasion.txt has 86270 words
# The book austen-sense.txt has 123514 words
# The book bible-kjv.txt has 848001 words
# The book blake-poems.txt has 8886 words
# The book bryant-stories.txt has 49404 words
# The book burgess-busterbrown.txt has 16305 words
# The book carroll-alice.txt has 28387 words
# The book chesterton-ball.txt has 86481 words
# The book chesterton-brown.txt has 80382 words
# The book chesterton-thursday.txt has 59297 words
# The book edgeworth-parents.txt has 177685 words
# The book melville-moby_dick.txt has 221023 words
# The book milton-paradise.txt has 91832 words
# The book shakespeare-caesar.txt has 23339 words
# The book shakespeare-hamlet.txt has 33477 words
# The book shakespeare-macbeth.txt has 20164 words
# The book whitman-leaves.txt has 138730 words

# %%
# more advanced, for those with some Python experience, or those who want to google around..
# solution 2: make a list of titles and a list of wordcounts, zip them together, then sort them based on wordcount
# starter code:

books = nltk.corpus.gutenberg.fileids()
Book_wordcount = []
titles = []
numwords = []
for title in books:
    book = nltk.corpus.gutenberg.raw(title)
    book = book.lower()
    book = book.replace('\n', ' ')
    book = book.split(' ')
    words = len(book)
    numwords.append(len(book))
    titles.append(title)

wordcount = zip(titles, numwords)

sorted_wordcount = sorted(wordcount, reverse = True,
                        key = lambda x: x[1])

print(f'{sorted_wordcount [0]} words')
# Out:
# ('bible-kjv.txt', 848001) words

# %% [markdown]
# ## Challenge 3: what are the most frequent words?
#
# `nltk` has a built-in function called `FreqDist` which counts up how many times each word in a text occurs. So, if you have a list called `words` which contains all the words in a book, you can find the frequencies of all of them by writing `freq = nltk.FreqDist(words)`. You can then get the e.g. ten most common words by writing `freq.most_common(10)`. What are the ten most common words in Jane Austen's "Emma"? What about Herman Melville's "Moby Dick"?

# %%
# starter code:

freqdist1 = []
freqdist2 = []
book1 = nltk.corpus.gutenberg.raw('austen-emma.txt')
words1 = book1.lower()
words1 = book1.replace('\n', ' ')
words1 = book1.replace('\r', ' ')
words1 = book1.split(' ')

book2 = nltk.corpus.gutenberg.raw('milton-paradise.txt')
words2 = book2.lower()
words2 = book2.replace('\n', ' ')
words2 = book2.replace('\r', ' ')
words2 = book2.split(' ')

freq1 = nltk.FreqDist(words1)
freq2 = nltk.FreqDist(words2)
freqdist1.append(freq1.most_common(10))
freqdist2.append(freq2.most_common(10))

freqdist1, freqdist2
# Out:
# ([[('to', 4475),
#    ('the', 4380),
#    ('', 3704),
#    ('of', 3647),
#    ('and', 3357),
#    ('a', 2707),
#    ('I', 2151),
#    ('was', 2063),
#    ('not', 1808),
#    ('in', 1791)]],
#  [[('and', 2704),
#    ('the', 2500),
#    ('to', 1752),
#    ('of', 1483),
#    ('', 1357),
#    ('in', 1080),
#    ('his', 981),
#    ('with', 871),
#    ('or', 562),
#    ('all', 553)]])

# %% [markdown]
# ## Challenge 4: Remove stopwords
#
# Often, the most frequent words are not the most interesting ones. Words like "a" and "the" are so common in English, that they don't really tell us much about the text. That is why we often remove "stopwords", that is, a list of the most common words in English, before e.g. counting frequencies. There are several of these lists available, in [English]((https://gist.github.com/sebleier/554280)) as well as other languages, such as [Danish](https://gist.github.com/berteltorp/0cf8a0c7afea7f25ed754f24cfc2467b). Below is some starter code to remove stopwords. Use these snippets to see what the most common words in Emma and Moby Dick are after removing these most common words.
#
# Hint: In Moby Dick, you will also have to remove the string `\r`, in addition to removing `\n`.

# %%
# create list of stopwords:
stopwords = ["", "i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you",
             "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself",
             "she", "her", "hers", "herself", "it", "its", "itself", "they", "them",
             "their", "theirs", "themselves", "what", "which", "who", "whom", "this",
             "that", "these", "those", "am", "is", "are", "was", "were", "be", "been",
             "being", "have", "has", "had", "having", "do", "does", "did", "doing", "a",
             "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
             "of", "at", "by", "for", "with", "about", "against", "between", "into", "through",
             "during", "before", "after", "above", "below", "to", "from", "up", "down", "in",
             "out", "on", "off", "over", "under", "again", "further", "then", "once", "here",
             "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more",
             "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so",
             "than", "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

freqdist = []
book = nltk.corpus.gutenberg.raw('austen-emma.txt')
# Book preprocessing:
words = book.lower()
words = book.replace('\n', ' ')
words = book.replace('\r', ' ')
words = book.split(' ')
# code to exclude stopwords from wordcount:
words = [word for word in words if word not in stopwords]

freq = nltk.FreqDist(words)


freqdist.append(freq.most_common(10))

freqdist
# Out:
# [[('I', 2151),
#   ('Mr.', 936),
#   ('could', 682),
#   ('would', 676),
#   ('Mrs.', 575),
#   ('Miss', 491),
#   ('must', 472),
#   ('much', 374),
#   ('said', 354),
#   ('every', 349)]]
